# %% [markdown]
#                                                              LEVEL 2 -[ TASK 1]

# %%
#Importing Liabraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Fetching CSV file

df = pd.read_csv("Dataset.csv")
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
table_booking_percent = (df['Has Table booking'].value_counts(normalize=True) * 100)
table_booking_percent
# Out:
# Has Table booking
# No     87.875615
# Yes    12.124385
# Name: proportion, dtype: float64

# %%
online_delivery_percent = (df['Has Online delivery'].value_counts(normalize=True) * 100)
online_delivery_percent
# Out:
# Has Online delivery
# No     74.337766
# Yes    25.662234
# Name: proportion, dtype: float64

# %%
df.groupby('Has Table booking')['Aggregate rating'].mean()
# Out:
# Has Table booking
# No     2.559359
# Yes    3.441969
# Name: Aggregate rating, dtype: float64

# %%
pd.crosstab(df['Price range'], df['Has Online delivery'])
# Out:
# Has Online delivery    No   Yes
# Price range
# 1                    3743   701
# 2                    1827  1286
# 3                     997   411
# 4                     533    53

# %%
pd.crosstab(df['Price range'], df['Has Online delivery'], normalize='index') * 100
# Out:
# Has Online delivery         No        Yes
# Price range
# 1                    84.225923  15.774077
# 2                    58.689367  41.310633
# 3                    70.809659  29.190341
# 4                    90.955631   9.044369

# %% [markdown]
#                                                              LEVEL 2 -[ TASK 2]

# %%
df['Price range'].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
df['Price range'].value_counts().idxmax()
# Out:
# np.int64(1)

# %%
df.groupby('Price range')['Aggregate rating'].mean()
# Out:
# Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate rating, dtype: float64

# %%
avg_ratings = df.groupby('Price range')['Aggregate rating'].mean()
best_price_range = avg_ratings.idxmax()
best_price_range
# Out:
# np.int64(4)

# %%
df[df['Price range'] == best_price_range]['Rating color'].mode()[0]
# Out:
# 'Yellow'

# %% [markdown]
#                                                              LEVEL 2 -[ TASK 3]

# %%
df['Name_Length'] = df['Restaurant Name'].str.len()

# %%
df['Address_Length'] = df['Address'].str.len()

# %%
df['Has_Table_Booking_Flag'] = df['Has Table booking'].map({'Yes': 1, 'No': 0})

# %%
df['Has_Online_Delivery_Flag'] = df['Has Online delivery'].map({'Yes': 1, 'No': 0})

# %%
df[['Restaurant Name','Name_Length','Address_Length',
    'Has_Table_Booking_Flag','Has_Online_Delivery_Flag']].head()
# Out:
#           Restaurant Name  Name_Length  Address_Length  \
# 0        Le Petit Souffle           16              71
# 1        Izakaya Kikufuji           16              67
# 2  Heat - Edsa Shangri-La           22              56
# 3                    Ooma            4              70
# 4             Sambo Kojin           11              64
#
#    Has_Table_Booking_Flag  Has_Online_Delivery_Flag
# 0                       1                         0
# 1                       1                         0
# 2                       1                         0
# 3                       0                         0
# 4                       1                         0
